# %%
#importing the necessary libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
# Reading data using the link
url = "http://bit.ly/w-data"
data = pd.read_csv(url)
data.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
# Plotting 
data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
plt.plot(data,linewidth=5)
plt.title("plots")
plt.show()

# %%
#Dividing data into attributes and labels
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values

# %%
#Splitting the data into train and test daata
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression  

reg = LinearRegression()  
reg.fit(X_train,y_train) 
print("trainig completed")
# Out:
# trainig completed

# %%
line = reg.coef_*X+reg.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %%
print(X_test) # Testing data - In Hours
y_pred = reg.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
df=pd.DataFrame({"Ground Truth value":y_test,"Predicted":y_pred})

df
# Out:
#    Ground Truth value  Predicted
# 0                  20  16.884145
# 1                  27  33.732261
# 2                  69  75.357018
# 3                  30  26.794801
# 4                  62  60.491033

# %%
hours = [[9.25]]
print(reg.predict(hours))
# Out:
# [93.69173249]

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002975

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression(max_iter=1000)
logreg.fit(X_train,y_train)

y_pred=logreg.predict(X_test)
print(y_pred)
# Out:
# [17 30 86 30 67]

# %%
hours = [[9.25]]
print(logreg.predict(hours))
# Out:
# [88]

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 5.6
